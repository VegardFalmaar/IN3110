# %%
from web_visualization import plot_reported_cases, read_from_file
import altair as alt
import pandas as pd

# %%
county = 'all counties'
start=pd.to_datetime('21.02.2020', utc=True, dayfirst=True)
end=pd.to_datetime('13.11.2020', utc=True, dayfirst=True)
df = read_from_file(county, start, end)
df = df.sort_values('Kumulativt antall')
alt.Chart(df).mark_bar().encode(
    x=alt.X('Dato'),#, bin=alt.Bin(maxbins=2000)),
    y=alt.Y('Kumulativt antall')
    #y=alt.Y('Nye tilfeller')
)
# Out:
# alt.Chart(...)

# %%
pd.to_datetime("01.03.2020", dayfirst=True)
